# %%
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
plt.plot([4, 4, 4, 4, 4])

# %%
plt.plot([-2, -1, 0, 1, 2], [-2, -1, 0, 1, 2])

# %%
plt.plot([-2, -1, 0, 1, 2], [0, 1, 2, 3, 4])
